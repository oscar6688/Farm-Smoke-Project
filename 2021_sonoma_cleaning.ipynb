# %%
import pandas as pd
import numpy as np
import csv
import re
from bs4 import BeautifulSoup

from tabula import read_pdf
from tabulate import tabulate
from itertools import chain
import matplotlib as plt

from ctypes.util import find_library
import camelot 


# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# If encounter SSL certify error - go to your Python 3.x.x folder and install Certification

# %%
csv = pd.read_csv('farm_smoke.csv')
sonoma_data = csv.query('County == "Sonoma"').copy().reset_index(drop=True)
sonoma_data
# Out:
#     County  Year                                              Links
# 0   Sonoma  2021  https://sonomacounty.ca.gov//Main%20County%20S...
# 1   Sonoma  2020  https://sonomacounty.ca.gov//Main%20County%20S...
# 2   Sonoma  2019  https://sonomacounty.ca.gov//Main%20County%20S...
# 3   Sonoma  2018  https://sonomacounty.ca.gov//Main%20County%20S...
# 4   Sonoma  2017  https://sonomacounty.ca.gov//Main%20County%20S...
# ..     ...   ...                                                ...
# 89  Sonoma  1932  https://sonomacounty.ca.gov//Main%20County%20S...
# 90  Sonoma  1931  https://sonomacounty.ca.gov//Main%20County%20S...
# 91  Sonoma  1930  https://sonomacounty.ca.gov//Main%20County%20S...
# 92  Sonoma  1929  https://sonomacounty.ca.gov//Main%20County%20S...
# 93  Sonoma  1928  https://sonomacounty.ca.gov//Main%20County%20S...
#
# [94 rows x 3 columns]

# %%
url = sonoma_data['Links'][0]
url
# Out:
# 'https://sonomacounty.ca.gov//Main%20County%20Site/Natural%20Resources/Agricultural%2C%20Weights%20%26%20Measures/Documents/Crop%20Reports/2021-Sonoma-County-Crop-Report.pdf'

# %%
# utilize camelot to read pdf file at page 12, capture precisely with stream and close up the row gap with row_tol = 10
tables = camelot.read_pdf('1111.pdf', pages='12', flavor='stream', row_tol=10)
data = tables[0].df
dat = tables[0].parsing_report
dat
# Out:
# {'accuracy': 99.66, 'whitespace': 9.68, 'order': 1, 'page': 12}

# %%
data
# Out:
#                        0     1                                        2  \
# 0                               TOP 13 BY VALUE - LISTED ALPHABETICALLY
# 1
# 2               Varietal  Year                                  Bearing
# 3         Cabernet Franc  2021                                    552.0
# 4                         2020                                    557.0
# 5               Cabernet  2021                                 12,293.0
# 6              Sauvignon  2020                                 12,089.0
# 7              Carignane  2021                                    156.0
# 8                         2020                                    158.0
# 9               Grenache  2021                                    211.0
# 10                        2020                                    203.0
# 11                Malbec  2021                                    422.0
# 12                        2020                                    414.0
# 13               Mataro/  2021                                     71.0
# 14             Mouvedere  2020                                     65.0
# 15                Merlot  2021                                  4,140.0
# 16                        2020                                  4,175.0
# 17          Petite Sirah  2021                                    651.0
# 18                        2020                                    641.0
# 19                        2021                                    242.0
# 20          Petit Verdot  2020                                    244.0
# 21            Pinot Noir  2021                                 12,608.0
# 22                        2020                                 12,516.0
# 23                        2021                                    278.0
# 24            Sangiovese  2020                                    279.0
# 25          Syrah-Shiraz  2021                                  1,326.0
# 26                        2020                                  1,352.0
# 27             Zinfandel  2021                                  4,613.0
# 28                        2020                                  4,654.0
# 29        TOTAL ALL REDS  2021                                 38,128.0
# 30  including other reds  2020                                 37,916.0
#
#               3         4          5           6             7
# 0
# 1       Acreage                       Production
# 2   Non-Bearing     Total       Tons       $/Ton   Total Value
# 3          33.0     585.0    1,150.4   $3,866.85    $4,448,400
# 4          29.0     586.0      942.4   $3,534.95    $3,331,300
# 5         429.0  12,722.0   41,114.6   $2,728.69  $112,189,000
# 6         631.0  12,720.0   31,137.9   $2,460.15   $76,603,900
# 7           2.0     158.0      280.7   $2,633.52      $739,200
# 8           6.0     164.0      257.9   $2,447.30      $631,200
# 9          55.0     266.0      898.4   $3,101.70    $2,786,600
# 10         58.0     261.0      751.7   $2,509.56    $1,886,400
# 11         26.0     448.0    1,577.2   $3,081.97    $4,860,900
# 12         16.0     430.0    1,004.8   $2,643.18    $2,655,900
# 13         11.0      82.0      179.1   $3,176.28      $568,900
# 14          8.0      73.0      108.3   $2,874.98      $311,400
# 15         17.0   4,157.0    7,828.5   $1,961.32   $15,354,200
# 16         17.0   4,192.0    5,652.8   $1,589.61    $8,985,700
# 17         26.0     677.0    2,163.9   $2,996.48    $6,484,100
# 18         42.0     683.0    1,622.1   $2,706.91    $4,390,900
# 19          6.0     248.0      983.1   $3,536.74    $3,477,000
# 20          7.0     251.0      494.6   $3,184.33    $1,575,000
# 21        265.0  12,873.0   48,496.5   $3,512.27  $170,332,800
# 22        497.0  13,013.0   29,263.7   $3,146.85   $92,088,500
# 23          4.0     282.0      879.7   $2,493.41    $2,193,500
# 24          4.0     283.0      398.9   $2,364.77      $943,300
# 25         34.0   1,360.0    2,450.6   $2,871.85    $7,037,800
# 26         29.0   1,381.0    1,581.5   $2,472.14    $3,909,700
# 27        116.0   4,729.0   11,660.0   $3,113.73   $36,306,100
# 28        105.0   4,759.0    8,397.0   $2,624.37   $22,036,800
# 29      1,056.0  39,184.0  121,693.0   $3,060.13  $372,396,400
# 30      1,493.0  39,409.0   82,910.2   $2,651.92  $219,871,200

# %%
# drop rows that is not helpful
data = data.drop([0,1,2], axis=0)

# %%
data
# Out:
#                        0     1         2        3         4          5  \
# 3         Cabernet Franc  2021     552.0     33.0     585.0    1,150.4
# 4                         2020     557.0     29.0     586.0      942.4
# 5               Cabernet  2021  12,293.0    429.0  12,722.0   41,114.6
# 6              Sauvignon  2020  12,089.0    631.0  12,720.0   31,137.9
# 7              Carignane  2021     156.0      2.0     158.0      280.7
# 8                         2020     158.0      6.0     164.0      257.9
# 9               Grenache  2021     211.0     55.0     266.0      898.4
# 10                        2020     203.0     58.0     261.0      751.7
# 11                Malbec  2021     422.0     26.0     448.0    1,577.2
# 12                        2020     414.0     16.0     430.0    1,004.8
# 13               Mataro/  2021      71.0     11.0      82.0      179.1
# 14             Mouvedere  2020      65.0      8.0      73.0      108.3
# 15                Merlot  2021   4,140.0     17.0   4,157.0    7,828.5
# 16                        2020   4,175.0     17.0   4,192.0    5,652.8
# 17          Petite Sirah  2021     651.0     26.0     677.0    2,163.9
# 18                        2020     641.0     42.0     683.0    1,622.1
# 19                        2021     242.0      6.0     248.0      983.1
# 20          Petit Verdot  2020     244.0      7.0     251.0      494.6
# 21            Pinot Noir  2021  12,608.0    265.0  12,873.0   48,496.5
# 22                        2020  12,516.0    497.0  13,013.0   29,263.7
# 23                        2021     278.0      4.0     282.0      879.7
# 24            Sangiovese  2020     279.0      4.0     283.0      398.9
# 25          Syrah-Shiraz  2021   1,326.0     34.0   1,360.0    2,450.6
# 26                        2020   1,352.0     29.0   1,381.0    1,581.5
# 27             Zinfandel  2021   4,613.0    116.0   4,729.0   11,660.0
# 28                        2020   4,654.0    105.0   4,759.0    8,397.0
# 29        TOTAL ALL REDS  2021  38,128.0  1,056.0  39,184.0  121,693.0
# 30  including other reds  2020  37,916.0  1,493.0  39,409.0   82,910.2
#
#             6             7
# 3   $3,866.85    $4,448,400
# 4   $3,534.95    $3,331,300
# 5   $2,728.69  $112,189,000
# 6   $2,460.15   $76,603,900
# 7   $2,633.52      $739,200
# 8   $2,447.30      $631,200
# 9   $3,101.70    $2,786,600
# 10  $2,509.56    $1,886,400
# 11  $3,081.97    $4,860,900
# 12  $2,643.18    $2,655,900
# 13  $3,176.28      $568,900
# 14  $2,874.98      $311,400
# 15  $1,961.32   $15,354,200
# 16  $1,589.61    $8,985,700
# 17  $2,996.48    $6,484,100
# 18  $2,706.91    $4,390,900
# 19  $3,536.74    $3,477,000
# 20  $3,184.33    $1,575,000
# 21  $3,512.27  $170,332,800
# 22  $3,146.85   $92,088,500
# 23  $2,493.41    $2,193,500
# 24  $2,364.77      $943,300
# 25  $2,871.85    $7,037,800
# 26  $2,472.14    $3,909,700
# 27  $3,113.73   $36,306,100
# 28  $2,624.37   $22,036,800
# 29  $3,060.13  $372,396,400
# 30  $2,651.92  $219,871,200

# %%
# rename my columns
new_columns = ['Varietal', 'Year', 'Bearing' , 'Non-Bearing', 'Total', 'Tons', '$/Ton', 'Total Value']
data = data.rename(columns=dict(zip(data.columns,new_columns)))
data
# Out:
#                 Varietal  Year   Bearing Non-Bearing     Total       Tons  \
# 3         Cabernet Franc  2021     552.0        33.0     585.0    1,150.4
# 4                         2020     557.0        29.0     586.0      942.4
# 5               Cabernet  2021  12,293.0       429.0  12,722.0   41,114.6
# 6              Sauvignon  2020  12,089.0       631.0  12,720.0   31,137.9
# 7              Carignane  2021     156.0         2.0     158.0      280.7
# 8                         2020     158.0         6.0     164.0      257.9
# 9               Grenache  2021     211.0        55.0     266.0      898.4
# 10                        2020     203.0        58.0     261.0      751.7
# 11                Malbec  2021     422.0        26.0     448.0    1,577.2
# 12                        2020     414.0        16.0     430.0    1,004.8
# 13               Mataro/  2021      71.0        11.0      82.0      179.1
# 14             Mouvedere  2020      65.0         8.0      73.0      108.3
# 15                Merlot  2021   4,140.0        17.0   4,157.0    7,828.5
# 16                        2020   4,175.0        17.0   4,192.0    5,652.8
# 17          Petite Sirah  2021     651.0        26.0     677.0    2,163.9
# 18                        2020     641.0        42.0     683.0    1,622.1
# 19                        2021     242.0         6.0     248.0      983.1
# 20          Petit Verdot  2020     244.0         7.0     251.0      494.6
# 21            Pinot Noir  2021  12,608.0       265.0  12,873.0   48,496.5
# 22                        2020  12,516.0       497.0  13,013.0   29,263.7
# 23                        2021     278.0         4.0     282.0      879.7
# 24            Sangiovese  2020     279.0         4.0     283.0      398.9
# 25          Syrah-Shiraz  2021   1,326.0        34.0   1,360.0    2,450.6
# 26                        2020   1,352.0        29.0   1,381.0    1,581.5
# 27             Zinfandel  2021   4,613.0       116.0   4,729.0   11,660.0
# 28                        2020   4,654.0       105.0   4,759.0    8,397.0
# 29        TOTAL ALL REDS  2021  38,128.0     1,056.0  39,184.0  121,693.0
# 30  including other reds  2020  37,916.0     1,493.0  39,409.0   82,910.2
#
#         $/Ton   Total Value
# 3   $3,866.85    $4,448,400
# 4   $3,534.95    $3,331,300
# 5   $2,728.69  $112,189,000
# 6   $2,460.15   $76,603,900
# 7   $2,633.52      $739,200
# 8   $2,447.30      $631,200
# 9   $3,101.70    $2,786,600
# 10  $2,509.56    $1,886,400
# 11  $3,081.97    $4,860,900
# 12  $2,643.18    $2,655,900
# 13  $3,176.28      $568,900
# 14  $2,874.98      $311,400
# 15  $1,961.32   $15,354,200
# 16  $1,589.61    $8,985,700
# 17  $2,996.48    $6,484,100
# 18  $2,706.91    $4,390,900
# 19  $3,536.74    $3,477,000
# 20  $3,184.33    $1,575,000
# 21  $3,512.27  $170,332,800
# 22  $3,146.85   $92,088,500
# 23  $2,493.41    $2,193,500
# 24  $2,364.77      $943,300
# 25  $2,871.85    $7,037,800
# 26  $2,472.14    $3,909,700
# 27  $3,113.73   $36,306,100
# 28  $2,624.37   $22,036,800
# 29  $3,060.13  $372,396,400
# 30  $2,651.92  $219,871,200

# %%
data['Varietal'].unique()
# Out:
# array(['Cabernet Franc', '', 'Cabernet', 'Sauvignon', 'Carignane',
#        'Grenache', 'Malbec', 'Mataro/', 'Mouvedere', 'Merlot',
#        'Petite Sirah', 'Petit Verdot', 'Pinot Noir', 'Sangiovese',
#        'Syrah-Shiraz', 'Zinfandel', 'TOTAL ALL REDS',
#        'including other reds'], dtype=object)

# %%
data['Varietal'] = data['Varietal'].replace('Mataro/', 'Mataro/Mouvedere')
data['Varietal'] = data['Varietal'].replace('Cabernet', 'Cabernet Sauvignon')
data['Varietal'] = data['Varietal'].replace(['', 'including other reds', 'Mouvedere', 'Sauvignon'], np.nan)
data = data.reset_index(drop=True)

data['Varietal'].unique()
# Out:
# array(['Cabernet Franc', nan, 'Cabernet Sauvignon', 'Carignane',
#        'Grenache', 'Malbec', 'Mataro/Mouvedere', 'Merlot', 'Petite Sirah',
#        'Petit Verdot', 'Pinot Noir', 'Sangiovese', 'Syrah-Shiraz',
#        'Zinfandel', 'TOTAL ALL REDS'], dtype=object)

# %%
data['Varietal'] = data['Varietal'].dropna().repeat(2).reset_index(drop=True)
data['County'] = 'Sonoma'

# %%
first_column = data.pop('County')
data.insert(0, 'County', first_column)
data
# Out:
#     County            Varietal  Year   Bearing Non-Bearing     Total  \
# 0   Sonoma      Cabernet Franc  2021     552.0        33.0     585.0
# 1   Sonoma      Cabernet Franc  2020     557.0        29.0     586.0
# 2   Sonoma  Cabernet Sauvignon  2021  12,293.0       429.0  12,722.0
# 3   Sonoma  Cabernet Sauvignon  2020  12,089.0       631.0  12,720.0
# 4   Sonoma           Carignane  2021     156.0         2.0     158.0
# 5   Sonoma           Carignane  2020     158.0         6.0     164.0
# 6   Sonoma            Grenache  2021     211.0        55.0     266.0
# 7   Sonoma            Grenache  2020     203.0        58.0     261.0
# 8   Sonoma              Malbec  2021     422.0        26.0     448.0
# 9   Sonoma              Malbec  2020     414.0        16.0     430.0
# 10  Sonoma    Mataro/Mouvedere  2021      71.0        11.0      82.0
# 11  Sonoma    Mataro/Mouvedere  2020      65.0         8.0      73.0
# 12  Sonoma              Merlot  2021   4,140.0        17.0   4,157.0
# 13  Sonoma              Merlot  2020   4,175.0        17.0   4,192.0
# 14  Sonoma        Petite Sirah  2021     651.0        26.0     677.0
# 15  Sonoma        Petite Sirah  2020     641.0        42.0     683.0
# 16  Sonoma        Petit Verdot  2021     242.0         6.0     248.0
# 17  Sonoma        Petit Verdot  2020     244.0         7.0     251.0
# 18  Sonoma          Pinot Noir  2021  12,608.0       265.0  12,873.0
# 19  Sonoma          Pinot Noir  2020  12,516.0       497.0  13,013.0
# 20  Sonoma          Sangiovese  2021     278.0         4.0     282.0
# 21  Sonoma          Sangiovese  2020     279.0         4.0     283.0
# 22  Sonoma        Syrah-Shiraz  2021   1,326.0        34.0   1,360.0
# 23  Sonoma        Syrah-Shiraz  2020   1,352.0        29.0   1,381.0
# 24  Sonoma           Zinfandel  2021   4,613.0       116.0   4,729.0
# 25  Sonoma           Zinfandel  2020   4,654.0       105.0   4,759.0
# 26  Sonoma      TOTAL ALL REDS  2021  38,128.0     1,056.0  39,184.0
# 27  Sonoma      TOTAL ALL REDS  2020  37,916.0     1,493.0  39,409.0
#
#          Tons      $/Ton   Total Value
# 0     1,150.4  $3,866.85    $4,448,400
# 1       942.4  $3,534.95    $3,331,300
# 2    41,114.6  $2,728.69  $112,189,000
# 3    31,137.9  $2,460.15   $76,603,900
# 4       280.7  $2,633.52      $739,200
# 5       257.9  $2,447.30      $631,200
# 6       898.4  $3,101.70    $2,786,600
# 7       751.7  $2,509.56    $1,886,400
# 8     1,577.2  $3,081.97    $4,860,900
# 9     1,004.8  $2,643.18    $2,655,900
# 10      179.1  $3,176.28      $568,900
# 11      108.3  $2,874.98      $311,400
# 12    7,828.5  $1,961.32   $15,354,200
# 13    5,652.8  $1,589.61    $8,985,700
# 14    2,163.9  $2,996.48    $6,484,100
# 15    1,622.1  $2,706.91    $4,390,900
# 16      983.1  $3,536.74    $3,477,000
# 17      494.6  $3,184.33    $1,575,000
# 18   48,496.5  $3,512.27  $170,332,800
# 19   29,263.7  $3,146.85   $92,088,500
# 20      879.7  $2,493.41    $2,193,500
# 21      398.9  $2,364.77      $943,300
# 22    2,450.6  $2,871.85    $7,037,800
# 23    1,581.5  $2,472.14    $3,909,700
# 24   11,660.0  $3,113.73   $36,306,100
# 25    8,397.0  $2,624.37   $22,036,800
# 26  121,693.0  $3,060.13  $372,396,400
# 27   82,910.2  $2,651.92  $219,871,200

# %%
data.to_csv('example.csv', index=False, encoding='utf-8')

# %%
# data['Varietal'] = data['Varietal'].replace('', method='ffill')
# data
