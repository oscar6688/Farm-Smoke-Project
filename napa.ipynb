# %%
# import necessary libraries
import pandas as pd
import requests
import csv
import re

from bs4 import BeautifulSoup

# %%
# web scrape Napa County url and get its html properties 

url = 'https://www.countyofnapa.org/Archive.aspx?AMID=39'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html')
tables = soup.find_all('table')



# variable to save our pdf_links to extract info
pdf_links_napa = []
valid_years_napa = []
# open csv file and write in our links 

with open('farm_smoke.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    headers = ["County", "Year","Links"]
    writer.writerow(headers)

    # index by the third table-tag 
    # first three were not relevant links 

    for table in tables[3:]:
        
        table_info = table.find('span', attrs={'class':'archive'})
        year_tag = table_info.find('span').text

        # if text does not contains "Spanish"
        if "Spanish" not in year_tag:

            # index first four digits
            valid_year = year_tag[:4]
            valid_years_napa.append(valid_year)

            # formulate the entire link
            pdf_link = 'https://www.countyofnapa.org/' + table_info.find('a').get('href')
            pdf_links_napa.append(pdf_link)

            # write into csv of web information
            writer.writerow(['Napa', valid_year, pdf_link])


# len(valid_years)
# len(pdf_links)

# quick math calculation 2014 - 1921 = 93; +1 for inclusive 
# starting in 2015, there is Spanish + English so 2 * 7 = 14 
# This give us 94 + 14 = 108 links 
# 108 - 7 = 101 links

# %%
# web scrape Mendocino County url and get its html properties 

url = 'https://www.mendocinocounty.org/government/agriculture'
response = requests.get(url)

# check status code for accessbility
# print(response.status_code)

soup = BeautifulSoup(response.text, 'html')

# years properties is separated into two properties

# attrs_code_1 = 'width: 8px; height: 8px; text-align: center; color: rgb(84, 141, 212); font-size: 20px; font-weight: bold;'
# attrs_code_2 = 'width: 8px; height: 8px; text-align: center; color: rgb(84, 141, 212); font-size: 20px; font-weight: bold; vertical-align: middle;'


# tables_1 = soup.find_all('td', attrs={'style':attrs_code_1})
# tables_2 = soup.find_all('td', attrs={'style':attrs_code_2})

tables = soup.find('table', attrs={'class':'subtitle'}).find_all('tr')

# # variable to save our pdf_links to extract info

pdf_links_mendocino = []
valid_years_mendocino = []
# open csv file and write in our links 

with open('farm_smoke.csv', 'a', newline='') as f:
    writer = csv.writer(f)

    for table in tables[1:]:
        for link in table.find_all('a', href=True):
            valid_year = link.text 
            pdf_link = link.get('href')
            valid_years_mendocino.append(valid_year)
            pdf_links_mendocino.append(pdf_link)

            writer.writerow(['Mendocino', valid_year, pdf_link])
            
            
        # year_tag = table_info.find('span').text

        # # if text does not contains "Spanish"
        # if "Spanish" not in year_tag:

        #     # index first four digits
        #     valid_year = year_tag[:4]
        #     valid_years.append(valid_year)

        #     # formulate the entire link
        #     pdf_link = 'https://www.countyofnapa.org/' + table_info.find('a').get('href')
        #     pdf_links.append(pdf_link)

        #     # write into csv of web information
        #     writer.writerow(['Napa', valid_year, pdf_link])

# %%
#  'Archive.aspx?ADID=91',
#  'Archive.aspx?ADID=88',
#  'Archive.aspx?ADID=90',
#  'Archive.aspx?ADID=89',
#  'Archive.aspx?ADID=87',
#  'Archive.aspx?ADID=86',
#  'Archive.aspx?ADID=85',
#  'Archive.aspx?ADID=80',
#  'Archive.aspx?ADID=84',
#  'Archive.aspx?ADID=71',
#  'Archive.aspx?ADID=83',
#  'Archive.aspx?ADID=82',
#  'Archive.aspx?ADID=81',
#  'Archive.aspx?ADID=79',
#  'Archive.aspx?ADID=70',
#  'Archive.aspx?ADID=78',
#  'Archive.aspx?ADID=77',
#  'Archive.aspx?ADID=76',
#  'Archive.aspx?ADID=75',
#  'Archive.aspx?ADID=57',
#  'Archive.aspx?ADID=74',
#  'Archive.aspx?ADID=73',
#  'Archive.aspx?ADID=72',
#  'Archive.aspx?ADID=69',
#  'Archive.aspx?ADID=68',
#  'Archive.aspx?ADID=64',
#  'Archive.aspx?ADID=67',
#  'Archive.aspx?ADID=66',
#  'Archive.aspx?ADID=65',
#  'Archive.aspx?ADID=63',
#  'Archive.aspx?ADID=62',
#  'Archive.aspx?ADID=61',
#  'Archive.aspx?ADID=56',
#  'Archive.aspx?ADID=58',
#  'Archive.aspx?ADID=60',
#  'Archive.aspx?ADID=55']

# %%
# url = 'https://www.countyofnapa.org/Archive.aspx?AMID=39'

# response = requests.get(url)
# table=pd.read_html(response.text)
# table
# Out:
# [    0                                                  1   2
#  0 NaN  Napa County Agricultural Crop Reports All Arch... NaN,
#                                         0             1
#  0  Napa County Agricultural Crop Reports  All Archives,
#      0                                        1
#  0 NaN  2021 (Spanish) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2021 (English) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2020 (Spanish) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2020 (English) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2019 (Spanish) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2019 (English) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2018 (Spanish) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2018 (English) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2017 (Spanish) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2017 (English) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2016 (English) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2016 (Spanish) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2015 (English) Annual Crop Report (PDF),
#      0                                        1
#  0 NaN  2015 (Spanish) Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2014 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2013 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2012 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2011 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2010 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2009 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2008 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2007 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2006 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2005 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2004 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2003 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2002 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2001 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  2000 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1999 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1998 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1997 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1996 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1995 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1994 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1993 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1992 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1991 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1990 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1989 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1988 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1987 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1986 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1985 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1984 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1983 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1982 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1981 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1980 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1979 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1978 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1977 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1976 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1975 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1974 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1973 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1972 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1971 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1970 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1969 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1968 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1967 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1966 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1965 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1964 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1963 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1962 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1961 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1960 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1959 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1958 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1957 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1956 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1955 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1954 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1953 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1952 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1951 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1950 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1949 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1948 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1947 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1946 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1945 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1944 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1943 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1942 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1941 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1940 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1939 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1938 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1937 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1936 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1935 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1934 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1933 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1932 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1931 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1930 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1929 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1928 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1927 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1926 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1925 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1924 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1923 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1922 Annual Crop Report (PDF),
#      0                              1
#  0 NaN  1921 Annual Crop Report (PDF)]
